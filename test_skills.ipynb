# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import rioxarray as rxr 

from rasterio.plot import plotting_extent

import earthpy as et
import earthpy.plot as ep

# %%
et.data.get_data("colorado-flood")
os.chdir(os.path.join(et.io.HOME, 'earth-analytics', 'data'))

# %%
sns.set(font_scale=1.5, style="white")

# %%
lidar_dem_path = os.path.join("colorado-flood", "spatial", "boulder-leehill-rd", "pre-flood", "lidar", "pre_DTM_hill.tif")

# %%
pre_DTM_hill = rxr.open_rasterio(lidar_dem_path, masked=True)

# %%
ep.plot_bands(pre_DTM_hill, cmap="gray", title="Lidar Digital Terrrian Model (DTM) OVerlayed on Top of Hillshade")

ax.set_axis_off()

# %%
fig, ax= plt.subplots(figsize=(10,6))

ep.plot_bands(pre_DTM_hill, ax=ax, cmap="viridis_r", alpha=0.5, title= "Lidar Digital Terrain Model (DTM) OVerlayed on Top of Hillside")

ax.set_axis_off()

plt.show()

# %%
pre_DTM_hill_data = rxr.open_rasterio(lidar_dem_path, masked=True)

# %%
lidar_dem_plot_ext= plotting_extent(pre_DTM_hill_data[0], pre_DTM_hill_data.rio.transform())

# %%
lidar_dem_plot_ext
# Out:
# (472000.0, 476000.0, 4434000.0, 4436000.0)

# %%
type(lidar_dem_plot_ext)
# Out:
# tuple

# %%
pre_DTM_hill_data.rio.bounds()
# Out:
# (472000.0, 4434000.0, 476000.0, 4436000.0)

# %%
type(pre_DTM_hill_data.rio.bounds())
# Out:
# tuple

# %%
fig, ax= plt.subplots(figsize=(10,6))

ep.plot_bands(pre_DTM_hill, ax=ax, cmap="viridis_r", alpha=0.5, title= "Lidar Digital Terrain Model (DTM) OVerlayed on Top of Hillside",
              extent=lidar_dem_plot_ext)

ax.set_axis_off()

plt.show()
